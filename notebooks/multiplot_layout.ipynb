# %% [markdown]
# #### Placing multiple plots on single layout
#
# Gnuplot have special layout for placing multiple plots on single layout and GnuplotRB supports this feature as well.

# %%
require 'gnuplotrb'
include GnuplotRB

sinx = Plot.new('sin(x)', title: 'Sin')
exp = Plot.new('exp(x)', title: 'Exp')
log = Plot.new('log(x)', title: 'Log')
sphere = Splot.new(
  ['sin(u)*cos(v), sin(u)*sin(v), cos(u)', title: 'Sphere'],
  parametric: true,
  urange: 0..Math::PI,
  vrange: 0..2*Math::PI,
  title: 'sphere',
  hidden3d: true,
  isosamples: 30
)
nil

# %% [markdown]
# To use this feature in GnuplotRB you just need to pass several Plot or Splot objects to constructor of Multiplot class. It's recommended to give him layout size too.

# %%
rows, cols = 2, 2
basic_four = Multiplot.new(sinx, exp, log, sphere, layout: [rows, cols])
# Out:
# #<GnuplotRB::Multiplot:0x00000001913128 @plots=Hamster::Vector[#<GnuplotRB::Plot:0x00000001904330 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000001904128 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Sin"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x0000000190bd88 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 277>>>, #<GnuplotRB::Plot:0x0000000190b8b0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000190b6a8 @type=:math_function, @data="exp(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Exp"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x0000000190b360 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 279>>>, #<GnuplotRB::Plot:0x0000000190aeb0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000190aca8 @type=:math_function, @data="log(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Log"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x0000000190a938 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 281>>>, #<GnuplotRB::Splot:0x0000000190a398 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000190a028 @type=:math_function, @data="sin(u)*cos(v), sin(u)*sin(v), cos(u)", @options=Hamster::Hash[:title => "Sphere"]>], @options=Hamster::Hash[:parametric => true, :urange => 0..3.141592653589793, :hidden3d => true, :title => "sphere", :vrange => 0..6.283185307179586, :isosamples => 30], @already_plotted=true, @cmd="splot ", @terminal=#<GnuplotRB::Terminal:0x00000001909ad8 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 283>>>], @options=Hamster::Hash[:layout => [2, 2]], @terminal=#<GnuplotRB::Terminal:0x00000001912ea8 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 285>>>

# %% [markdown]
# You can also set one title for the whole layout.

# %%
basic_four.title('Multiplot example')
# Out:
# #<GnuplotRB::Multiplot:0x00000000ff84a8 @plots=Hamster::Vector[#<GnuplotRB::Plot:0x00000001904330 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000001904128 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Sin"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x0000000190bd88 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 277>>>, #<GnuplotRB::Plot:0x0000000190b8b0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000190b6a8 @type=:math_function, @data="exp(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Exp"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x0000000190b360 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 279>>>, #<GnuplotRB::Plot:0x0000000190aeb0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000190aca8 @type=:math_function, @data="log(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Log"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x0000000190a938 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 281>>>, #<GnuplotRB::Splot:0x0000000190a398 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000190a028 @type=:math_function, @data="sin(u)*cos(v), sin(u)*sin(v), cos(u)", @options=Hamster::Hash[:title => "Sphere"]>], @options=Hamster::Hash[:parametric => true, :urange => 0..3.141592653589793, :hidden3d => true, :title => "sphere", :vrange => 0..6.283185307179586, :isosamples => 30], @already_plotted=true, @cmd="splot ", @terminal=#<GnuplotRB::Terminal:0x00000001909ad8 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 283>>>], @options=Hamster::Hash[:layout => [2, 2], :title => ["Multiplot example"]], @terminal=#<GnuplotRB::Terminal:0x00000000ffd228 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 289>>>

# %% [markdown]
# You can change layout size anytime (if it will have less cells than you have plots, they will be overriden by each other).

# %%
basic_two = Multiplot.new(sinx, sphere, layout: [1,2])
# Out:
# #<GnuplotRB::Multiplot:0x00000001222710 @plots=Hamster::Vector[#<GnuplotRB::Plot:0x00000001904330 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000001904128 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Sin"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x0000000190bd88 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 277>>>, #<GnuplotRB::Splot:0x0000000190a398 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000190a028 @type=:math_function, @data="sin(u)*cos(v), sin(u)*sin(v), cos(u)", @options=Hamster::Hash[:title => "Sphere"]>], @options=Hamster::Hash[:parametric => true, :urange => 0..3.141592653589793, :hidden3d => true, :title => "sphere", :vrange => 0..6.283185307179586, :isosamples => 30], @already_plotted=true, @cmd="splot ", @terminal=#<GnuplotRB::Terminal:0x00000001909ad8 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 283>>>], @options=Hamster::Hash[:layout => [1, 2]], @terminal=#<GnuplotRB::Terminal:0x000000012223a0 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 293>>>

# %%
basic_two.layout(2,1)
# Out:
# #<GnuplotRB::Multiplot:0x000000012764c8 @plots=Hamster::Vector[#<GnuplotRB::Plot:0x00000001904330 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000001904128 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Sin"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x0000000190bd88 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 277>>>, #<GnuplotRB::Splot:0x0000000190a398 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x0000000190a028 @type=:math_function, @data="sin(u)*cos(v), sin(u)*sin(v), cos(u)", @options=Hamster::Hash[:title => "Sphere"]>], @options=Hamster::Hash[:parametric => true, :urange => 0..3.141592653589793, :hidden3d => true, :title => "sphere", :vrange => 0..6.283185307179586, :isosamples => 30], @already_plotted=true, @cmd="splot ", @terminal=#<GnuplotRB::Terminal:0x00000001909ad8 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 283>>>], @options=Hamster::Hash[:layout => [2, 1]], @terminal=#<GnuplotRB::Terminal:0x00000001276248 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 297>>>
