# %% [markdown]
# #### Placing multiple plots on single layout
#
# Gnuplot have special layout for placing multiple plots on single layout and GnuplotRB supports this feature as well.

# %%
require 'gnuplotrb'
include GnuplotRB

sinx = Plot.new('sin(x)', title: 'Sin')
exp = Plot.new('exp(x)', title: 'Exp')
log = Plot.new('log(x)', title: 'Log')
sphere = Splot.new(
  ['sin(u)*cos(v), sin(u)*sin(v), cos(u)', title: 'Sphere'],
  parametric: true,
  urange: 0..Math::PI,
  vrange: 0..2*Math::PI,
  title: 'sphere',
  hidden3d: true,
  isosamples: 30
)
nil

# %% [markdown]
# To use this feature in GnuplotRB you just need to pass several Plot or Splot objects to constructor of Multiplot class. It's recommended to give him layout size too.

# %%
rows, cols = 2, 2
basic_four = Multiplot.new(sinx, exp, log, sphere, layout: [rows, cols])
# Out:
# #<GnuplotRB::Multiplot:0x00000000e160e0 @plots=Hamster::Vector[#<GnuplotRB::Plot:0x00000000dfc0f0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e01898 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Sin"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x00000000e01280 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 106>>>, #<GnuplotRB::Plot:0x00000000e00b00 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e00600 @type=:math_function, @data="exp(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Exp"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x00000000e00100 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 108>>>, #<GnuplotRB::Plot:0x00000000e07ae0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e075b8 @type=:math_function, @data="log(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Log"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x00000000e06d98 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 110>>>, #<GnuplotRB::Splot:0x00000000e06168 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e055b0 @type=:math_function, @data="sin(u)*cos(v), sin(u)*sin(v), cos(u)", @options=Hamster::Hash[:title => "Sphere"]>], @options=Hamster::Hash[:urange => 0..3.141592653589793, :parametric => true, :vrange => 0..6.283185307179586, :hidden3d => true, :title => "sphere", :isosamples => 30], @already_plotted=true, @cmd="splot ", @terminal=#<GnuplotRB::Terminal:0x00000000e0b258 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 112>>>], @options=Hamster::Hash[:layout => [2, 2]], @terminal=#<GnuplotRB::Terminal:0x00000000e15cd0 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 114>>>

# %% [markdown]
# You can also set one title for the whole layout.

# %%
basic_four.title('Multiplot example')
# Out:
# #<GnuplotRB::Multiplot:0x000000010559f0 @plots=Hamster::Vector[#<GnuplotRB::Plot:0x00000000dfc0f0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e01898 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Sin"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x00000000e01280 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 106>>>, #<GnuplotRB::Plot:0x00000000e00b00 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e00600 @type=:math_function, @data="exp(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Exp"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x00000000e00100 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 108>>>, #<GnuplotRB::Plot:0x00000000e07ae0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e075b8 @type=:math_function, @data="log(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Log"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x00000000e06d98 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 110>>>, #<GnuplotRB::Splot:0x00000000e06168 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e055b0 @type=:math_function, @data="sin(u)*cos(v), sin(u)*sin(v), cos(u)", @options=Hamster::Hash[:title => "Sphere"]>], @options=Hamster::Hash[:urange => 0..3.141592653589793, :parametric => true, :vrange => 0..6.283185307179586, :hidden3d => true, :title => "sphere", :isosamples => 30], @already_plotted=true, @cmd="splot ", @terminal=#<GnuplotRB::Terminal:0x00000000e0b258 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 112>>>], @options=Hamster::Hash[:layout => [2, 2], :title => ["Multiplot example"]], @terminal=#<GnuplotRB::Terminal:0x000000010555e0 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 118>>>

# %% [markdown]
# You can change layout size anytime (if it will have less cells than you have plots, they will be overriden by each other).

# %%
basic_two = Multiplot.new(sinx, sphere, layout: [1,2])
# Out:
# #<GnuplotRB::Multiplot:0x0000000108e548 @plots=Hamster::Vector[#<GnuplotRB::Plot:0x00000000dfc0f0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e01898 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Sin"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x00000000e01280 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 106>>>, #<GnuplotRB::Splot:0x00000000e06168 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e055b0 @type=:math_function, @data="sin(u)*cos(v), sin(u)*sin(v), cos(u)", @options=Hamster::Hash[:title => "Sphere"]>], @options=Hamster::Hash[:urange => 0..3.141592653589793, :parametric => true, :vrange => 0..6.283185307179586, :hidden3d => true, :title => "sphere", :isosamples => 30], @already_plotted=true, @cmd="splot ", @terminal=#<GnuplotRB::Terminal:0x00000000e0b258 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 112>>>], @options=Hamster::Hash[:layout => [1, 2]], @terminal=#<GnuplotRB::Terminal:0x0000000108d0a8 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 122>>>

# %%
basic_two.layout(2,1)
# Out:
# #<GnuplotRB::Multiplot:0x000000011b7ed8 @plots=Hamster::Vector[#<GnuplotRB::Plot:0x00000000dfc0f0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e01898 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:title => "Sin"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x00000000e01280 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 106>>>, #<GnuplotRB::Splot:0x00000000e06168 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e055b0 @type=:math_function, @data="sin(u)*cos(v), sin(u)*sin(v), cos(u)", @options=Hamster::Hash[:title => "Sphere"]>], @options=Hamster::Hash[:urange => 0..3.141592653589793, :parametric => true, :vrange => 0..6.283185307179586, :hidden3d => true, :title => "sphere", :isosamples => 30], @already_plotted=true, @cmd="splot ", @terminal=#<GnuplotRB::Terminal:0x00000000e0b258 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 112>>>], @options=Hamster::Hash[:layout => [2, 1]], @terminal=#<GnuplotRB::Terminal:0x000000011b7be0 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 126>>>

# %% [markdown]
# You can also use size and origin options instead of layout. It's useful when you need to have different cells.

# %%
minisinx = sinx.options(size: [0.6,1.0], origin: [0,0])
minilog = log.options(size: [0.4,0.5], origin: [0.6,0])
minisphere = sphere.options(size: [0.4,0.5], origin: [0.6,0.5])
Multiplot.new(minisinx, minilog, minisphere)
# Out:
# #<GnuplotRB::Multiplot:0x000000012209d8 @plots=Hamster::Vector[#<GnuplotRB::Plot:0x00000001223c78 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e01898 @type=:math_function, @data="sin(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:origin => [0, 0], :title => "Sin", :size => [0.6, 1.0]], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x00000001223778 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 130>>>, #<GnuplotRB::Plot:0x00000001222fd0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e075b8 @type=:math_function, @data="log(x)", @options=Hamster::Hash[]>], @options=Hamster::Hash[:origin => [0.6, 0], :title => "Log", :size => [0.4, 0.5]], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x00000001222bc0 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 132>>>, #<GnuplotRB::Splot:0x00000001221ea0 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000000e055b0 @type=:math_function, @data="sin(u)*cos(v), sin(u)*sin(v), cos(u)", @options=Hamster::Hash[:title => "Sphere"]>], @options=Hamster::Hash[:urange => 0..3.141592653589793, :parametric => true, :origin => [0.6, 0.5], :vrange => 0..6.283185307179586, :hidden3d => true, :title => "sphere", :size => [0.4, 0.5], :isosamples => 30], @already_plotted=true, @cmd="splot ", @terminal=#<GnuplotRB::Terminal:0x000000012210e0 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 134>>>], @options=Hamster::Hash[], @terminal=#<GnuplotRB::Terminal:0x000000012205a0 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 136>>>
