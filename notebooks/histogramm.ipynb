# %% [markdown]
# ### Histogramm example
# Example's idea taken from https://github.com/rdp/ruby_gnuplot/blob/master/examples/histogram.rb .

# %%
require 'gnuplotrb'
include GnuplotRB

titles = %w{decade Austria Hungary  Belgium}

data = [
    ['1891-1900',  234081,  181288,  18167],
    ['1901-1910',  668209,  808511,  41635],
    ['1911-1920',  453649,  442693,  33746],
    ['1921-1930',  32868,   30680,   15846],
    ['1931-1940',  3563,    7861,    4817],
    ['1941-1950',  24860,   3469,    12189],
    ['1951-1960',  67106,   36637,   18575],
    ['1961-1970',  20621,   5401,    9192],
]

x = data.map(&:first)
datasets = (1..3).map do |col|
  y = data.map { |row| row[col] }
  Dataset.new([x, y], using: '2:xtic(1)', title: titles[col], file: true)
end

histogramm = Plot.new(
  *datasets,
  title: 'Histogram example',
  style: 'data histograms',
  xtics: 'nomirror rotate by -45'
)

histogramm.to_png('./histogramm.png', size: [600, 600])
File.open('./histogramm.png')
# Out:
# #<File:./histogramm.png>

# %% [markdown]
# The same data may be also plotted in another form.

# %%
linespoints = histogramm.style('data linespoints')
linespoints.to_png('./linespoints.png', size: [600, 600])
File.open('./linespoints.png')
# Out:
# #<File:./linespoints.png>

# %% [markdown]
# #### Set fill with multi word option key

# %%
titles = %w{decade Build Test Deploy Overall}
data = [
    [1,  312, 525,  215, 1052],
    [2,  630, 1050, 441, 2121],
    [3,  315, 701,  370, 1386],
    [4,  312, 514,  220, 1046]
]
x = data.map(&:first)
datasets = (1..4).map do |col|
    y = data.map { |row| row[col] }
    Dataset.new([x, y], using: '2:xtic(1)', title: titles[col], file: true)
end

Plot.new(
    *datasets,
    style_data: 'histograms',
    style_fill: 'pattern border',
    yrange: 0..2200,
    xlabel: 'Number of test',
    ylabel: 'Time, s',
    title: 'Time spent to run deploy pipeline'
)
# Out:
# #<GnuplotRB::Plot:0x000000028e49f8 @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x000000028e4598 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000002904848 @stored_in_file=true, @file_name="tmp_data20150623-11122-17snub-0">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => "Build"]>, #<GnuplotRB::Dataset:0x000000028d3e78 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000028ea808 @stored_in_file=true, @file_name="tmp_data20150623-11122-10rq636-0">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => "Test"]>, #<GnuplotRB::Dataset:0x000000028d36d0 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000028e85f8 @stored_in_file=true, @file_name="tmp_data20150623-11122-17vi05c-0">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => "Deploy"]>, #<GnuplotRB::Dataset:0x000000028d2c30 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000028e6500 @stored_in_file=true, @file_name="tmp_data20150623-11122-wazvdz-0">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => "Overall"]>], @options=Hamster::Hash[:style_data => "histograms", :ylabel => "Time, s", :yrange => 0..2200, :xlabel => "Number of test", :style_fill => "pattern border", :title => "Time spent to run deploy pipeline"], @already_plotted=true, @cmd="plot ", @terminal=#<GnuplotRB::Terminal:0x000000028d1a10 @cmd="gnuplot 2>&1", @current_datablock=0, @err_array=[], @in=#<IO:fd 33>>>
